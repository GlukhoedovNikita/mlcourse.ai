# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("dark")
sns.set_palette("RdBu")
sns.set_context(
    "notebook", font_scale=1.5, rc={"figure.figsize": (15, 5), "axes.titlesize": 18}
)

# %%
df = pd.read_csv('howpop_train.csv')
df
# Out:
#                                                      url        domain  \
# 0                       https://habrahabr.ru/post/18284/  habrahabr.ru
# 1                       https://habrahabr.ru/post/18285/  habrahabr.ru
# 2                       https://habrahabr.ru/post/18286/  habrahabr.ru
# 3                       https://habrahabr.ru/post/18291/  habrahabr.ru
# 4                       https://geektimes.ru/post/18294/  geektimes.ru
# ...                                                  ...           ...
# 134132  https://habrahabr.ru/company/mailru/blog/314014/  habrahabr.ru
# 134133                 https://geektimes.ru/post/282086/  geektimes.ru
# 134134                 https://geektimes.ru/post/282090/  geektimes.ru
# 134135                 https://geektimes.ru/post/282092/  geektimes.ru
# 134136                 https://habrahabr.ru/post/314088/  habrahabr.ru
#
#         post_id            published      author     flow  polling  \
# ...

# %%
df.drop(filter(lambda c: c.endswith('_lognorm'),df.columns),axis=1,inplace=True)

# %%
df['published'] = pd.to_datetime(df.published , yearfirst=True)
df['published'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['year'] = [d.year for d in df.published]
df['month'] = [d.month for d in df.published]
df['dayofweek'] = [d.isoweekday() for d in df.published]
df['hour'] = [d.hour for d in df.published]

# %%
df
# Out:
#                                                      url        domain  \
# 0                       https://habrahabr.ru/post/18284/  habrahabr.ru
# 1                       https://habrahabr.ru/post/18285/  habrahabr.ru
# 2                       https://habrahabr.ru/post/18286/  habrahabr.ru
# 3                       https://habrahabr.ru/post/18291/  habrahabr.ru
# 4                       https://geektimes.ru/post/18294/  geektimes.ru
# ...                                                  ...           ...
# 134132  https://habrahabr.ru/company/mailru/blog/314014/  habrahabr.ru
# 134133                 https://geektimes.ru/post/282086/  geektimes.ru
# 134134                 https://geektimes.ru/post/282090/  geektimes.ru
# 134135                 https://geektimes.ru/post/282092/  geektimes.ru
# 134136                 https://habrahabr.ru/post/314088/  habrahabr.ru
#
#         post_id           published      author     flow  polling  \
# ...

# %%
df[['month','year']].value_counts()
# Out:
# month  year
# 3      2015    2189
#        2016    2115
# 7      2015    2111
# 4      2015    2110
# 12     2015    2084
#                ...
# 6      2008     599
# 4      2008     597
# 3      2008     545
# 2      2008     496
# 1      2008     435
# Length: 106, dtype: int64

# %%
df_quest_2 = df.loc[(df['month']==3)&(df['year']==2015)]
df_quest_2
# Out:
#                                                      url        domain  \
# 97666                  https://habrahabr.ru/post/251783/  habrahabr.ru
# 97667  https://habrahabr.ru/company/kolibrios/blog/23...  habrahabr.ru
# 97668                  https://habrahabr.ru/post/286286/  habrahabr.ru
# 97669                  https://habrahabr.ru/post/251347/  habrahabr.ru
# 97670                  https://habrahabr.ru/post/251765/  habrahabr.ru
# ...                                                  ...           ...
# 99850                  https://geektimes.ru/post/248196/  geektimes.ru
# 99851                  https://habrahabr.ru/post/254561/  habrahabr.ru
# 99852                  https://habrahabr.ru/post/254563/  habrahabr.ru
# 99853                  https://habrahabr.ru/post/254565/  habrahabr.ru
# 99854                  https://geektimes.ru/post/248200/  geektimes.ru
#
#        post_id           published             author     flow  polling  \
# ...

# %%
df_quest_2.loc[df_quest_2['domain']=='habrahabr.ru'].shape[0] , \
df_quest_2.loc[df_quest_2['domain']!='habrahabr.ru'].shape[0]
# Out:
# (1434, 755)

# %%
df_quest_2.loc[(df_quest_2['dayofweek']==6)&(df_quest_2['domain']=='habrahabr.ru')].shape[0] ,\
df_quest_2.loc[(df_quest_2['dayofweek']==6)&(df_quest_2['domain']!='habrahabr.ru')].shape[0]
# Out:
# (58, 57)

# %%
df.groupby('hour')['views'].agg('mean')
# Out:
# hour
# 0     17546.982349
# 1     17717.709114
# 2     17328.690581
# 3     18370.017972
# 4     20678.389091
# 5     17218.894242
# 6     21354.310115
# 7     19093.953408
# 8     16014.419048
# 9     16906.059099
# 10    16580.889909
# 11    16331.186818
# 12    16209.416141
# 13    15822.606055
# 14    15773.203785
# 15    14739.224017
# 16    16583.150731
# 17    15814.881313
# 18    16731.210843
# 19    16926.284287
# 20    18134.614873
# 21    17605.819064
# 22    18365.387460
# 23    17631.345932
# Name: views, dtype: float64

# %%
df.groupby(['hour','domain'])['comments'].agg('max')
# Out:
# hour  domain
# 0     geektimes.ru     897
#       habrahabr.ru    1261
# 1     geektimes.ru    1118
#       habrahabr.ru    1729
# 2     geektimes.ru    2266
#       habrahabr.ru     699
# 3     geektimes.ru     886
#       habrahabr.ru     727
# 4     geektimes.ru     669
#       habrahabr.ru    1475
# 5     geektimes.ru     832
#       habrahabr.ru     518
# 6     geektimes.ru     793
#       habrahabr.ru     574
# 7     geektimes.ru     463
#       habrahabr.ru     868
# 8     geektimes.ru     347
#       habrahabr.ru     768
# 9     geektimes.ru     651
#       habrahabr.ru    2194
# 10    geektimes.ru     628
#       habrahabr.ru    1585
# 11    geektimes.ru     873
#       habrahabr.ru    1070
# 12    geektimes.ru    1214
#       habrahabr.ru    1075
# 13    geektimes.ru     723
#       habrahabr.ru    1236
# 14    geektimes.ru     723
#       habrahabr.ru    1008
# 15    geektimes.ru     908
#       habrahabr.ru     796
# 16    geektimes.ru    1039
# ...

# %%
df.groupby(['hour','domain'])['comments'].agg('mean')
# Out:
# hour  domain
# 0     geektimes.ru    57.264531
#       habrahabr.ru    44.037267
# 1     geektimes.ru    57.920755
#       habrahabr.ru    45.103399
# 2     geektimes.ru    56.963115
#       habrahabr.ru    44.959740
# 3     geektimes.ru    66.993658
#       habrahabr.ru    47.077419
# 4     geektimes.ru    63.327327
#       habrahabr.ru    49.458931
# 5     geektimes.ru    55.386555
#       habrahabr.ru    44.877651
# 6     geektimes.ru    63.425926
#       habrahabr.ru    45.240299
# 7     geektimes.ru    53.501333
#       habrahabr.ru    39.651929
# 8     geektimes.ru    47.152439
#       habrahabr.ru    33.119099
# 9     geektimes.ru    48.836422
#       habrahabr.ru    33.399345
# 10    geektimes.ru    45.518372
#       habrahabr.ru    30.089079
# 11    geektimes.ru    48.699629
#       habrahabr.ru    30.183618
# 12    geektimes.ru    49.361504
#       habrahabr.ru    30.585103
# 13    geektimes.ru    47.899783
#       habrahabr.ru    31.688634
# ...

# %%
df.loc[df['dayofweek']==1].groupby('hour')['url'].agg('count')
# Out:
# hour
# 0      537
# 1      415
# 2      320
# 3      209
# 4      173
# 5      111
# 6      226
# 7      279
# 8      477
# 9      962
# 10    1467
# 11    1862
# 12    1994
# 13    1915
# 14    1895
# 15    1823
# 16    1694
# 17    1537
# 18    1404
# 19    1077
# 20     888
# 21     835
# 22     734
# 23     802
# Name: url, dtype: int64

# %%
df.loc[df['dayofweek']==6].groupby('hour')['url'].agg('count')
# Out:
# hour
# 0     492
# 1     376
# 2     263
# 3     182
# 4     107
# 5     105
# 6      69
# 7      95
# 8     118
# 9     177
# 10    237
# 11    367
# 12    449
# 13    502
# 14    519
# 15    556
# 16    479
# 17    494
# 18    468
# 19    441
# 20    459
# 21    480
# 22    482
# 23    463
# Name: url, dtype: int64
